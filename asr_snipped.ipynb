# %%
import tensorflow as tf

# %%
import librosa as lb
import numpy as np
# Out:
# C:\Users\Karthik\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\numba\errors.py:137: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
X, sample_rate = lb.load('song.wav')

# %%
stft = np.abs(lb.stft(X))
mfccs = np.mean(lb.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
chroma = np.mean(lb.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
mel = np.mean(lb.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
contrast = np.mean(lb.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
tonnetz = np.mean(lb.feature.tonnetz(y=lb.effects.harmonic(X), sr=sample_rate).T,axis=0)

# %%
np.shape(stft)
# Out:
# (1025, 431)

# %%
import matplotlib.pyplot as plt

# %%
import librosa.display
librosa.display.waveplot(X,sr=sample_rate)
plt.show()

# %%
# Xdb = librosa.amplitude_to_db(abs(X))
librosa.display.specshow(stft, sr=sample_rate, x_axis='time', y_axis='hz') 
# plt.ylim(0,500)
plt.colorbar()
plt.show()

# %%
X1, sample_rate1 = lb.load('vocals.wav')
stft1 = np.abs(lb.stft(X1))
mfccs1 = np.mean(lb.feature.mfcc(y=X1, sr=sample_rate1, n_mfcc=40).T,axis=0)
chroma1 = np.mean(lb.feature.chroma_stft(S=stft1, sr=sample_rate1).T,axis=0)
mel1 = np.mean(lb.feature.melspectrogram(X1, sr=sample_rate1).T,axis=0)
contrast1 = np.mean(lb.feature.spectral_contrast(S=stft1, sr=sample_rate1).T,axis=0)
tonnetz1 = np.mean(lb.feature.tonnetz(y=lb.effects.harmonic(X1), sr=sample_rate1).T,axis=0)

# %%
librosa.display.waveplot(X1,sr=sample_rate1)
plt.show()

# %%
librosa.display.specshow(stft1, sr=sample_rate1, x_axis='time', y_axis='hz') 
# plt.ylim(0,4000)
plt.colorbar()
plt.show()

# %%
X2, sample_rate2 = lb.load('music.wav')
stft2 = np.abs(lb.stft(X2))
mfccs2 = np.mean(lb.feature.mfcc(y=X2, sr=sample_rate2, n_mfcc=40).T,axis=0)
chroma2 = np.mean(lb.feature.chroma_stft(S=stft2, sr=sample_rate2).T,axis=0)
mel2 = np.mean(lb.feature.melspectrogram(X2, sr=sample_rate2).T,axis=0)
contrast2 = np.mean(lb.feature.spectral_contrast(S=stft2, sr=sample_rate2).T,axis=0)
tonnetz2 = np.mean(lb.feature.tonnetz(y=librosa.effects.harmonic(X2), sr=sample_rate2).T,axis=0)

# %%
librosa.display.waveplot(X2,sr=sample_rate2)
plt.show()

# %%
# Xdb = librosa.amplitude_to_db(abs(X))
librosa.display.specshow(stft2, sr=sample_rate2, x_axis='time', y_axis='hz') 
# plt.ylim(0,1000)
plt.colorbar()
plt.show()

# %%
X_emp = lb.effects.preemphasis(X)
# Out:
# C:\Users\Karthik\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\scipy\signal\signaltools.py:1333: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# C:\Users\Karthik\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\scipy\signal\signaltools.py:1336: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# ...

# %%
stft_e = np.abs(lb.stft(X_emp))
mfccs_e = np.mean(lb.feature.mfcc(y=X_emp, sr=sample_rate, n_mfcc=40).T,axis=0)
chroma_e = np.mean(lb.feature.chroma_stft(S=stft_e, sr=sample_rate).T,axis=0)
mel_e = np.mean(lb.feature.melspectrogram(X_emp, sr=sample_rate).T,axis=0)
contrast_e = np.mean(lb.feature.spectral_contrast(S=stft_e, sr=sample_rate).T,axis=0)
tonnetz_e = np.mean(lb.feature.tonnetz(y=librosa.effects.harmonic(X_emp), sr=sample_rate).T,axis=0)

# %%
librosa.display.waveplot(X_emp,sr=sample_rate)
plt.show()

# %%
# Xdb = librosa.amplitude_to_db(abs(X))
librosa.display.specshow(stft_e, sr=sample_rate, x_axis='time', y_axis='hz') 
# plt.ylim(0,1000)
plt.colorbar()
plt.show()

# %%
import keras
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-c74e2bd4ca71> in <module>()
# ----> 1 import keras
#
# C:\Users\Karthik\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\keras\__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# C:\Users\Karthik\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\keras\utils\__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7 from . import losses_utils
#       8 from . import metrics_utils
#
# C:\Users\Karthik\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\keras\utils\conv_utils.py in <module>()
#       7 from six.moves import range
# ...
