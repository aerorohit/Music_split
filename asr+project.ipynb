# %%
import tensorflow as tf

# %%
import librosa as lb
import numpy as np

# %%
X, sample_rate = lb.load('perfect-02.wav')

# %%
stft = np.abs(lb.stft(X))
mfccs = np.mean(lb.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
chroma = np.mean(lb.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
mel = np.mean(lb.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
contrast = np.mean(lb.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
tonnetz = np.mean(lb.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X)
plt.show()
plt.plot(mfccs)
plt.show()
plt.plot(chroma)
plt.show()
plt.plot(mel)
plt.show()
plt.plot(contrast)
plt.show()
plt.plot(tonnetz)
plt.show()

# %%
X1, sample_rate1 = lb.load('perfect-01.wav')
stft1 = np.abs(lb.stft(X1))
mfccs1 = np.mean(lb.feature.mfcc(y=X1, sr=sample_rate1, n_mfcc=40).T,axis=0)
chroma1 = np.mean(lb.feature.chroma_stft(S=stft1, sr=sample_rate1).T,axis=0)
mel1 = np.mean(lb.feature.melspectrogram(X1, sr=sample_rate1).T,axis=0)
contrast1 = np.mean(lb.feature.spectral_contrast(S=stft1, sr=sample_rate1).T,axis=0)
tonnetz1 = np.mean(lb.feature.tonnetz(y=librosa.effects.harmonic(X1), sr=sample_rate1).T,axis=0)

# %%
plt.plot(X1)
plt.show()
plt.plot(mfccs1)
plt.show()
plt.plot(chroma1)
plt.show()
plt.plot(mel1)
plt.show()
plt.plot(contrast1)
plt.show()
plt.plot(tonnetz1)
plt.show()

# %%
X2, sample_rate2 = lb.load('perfect.wav')
stft2 = np.abs(lb.stft(X2))
mfccs2 = np.mean(lb.feature.mfcc(y=X2, sr=sample_rate2, n_mfcc=40).T,axis=0)
chroma2 = np.mean(lb.feature.chroma_stft(S=stft2, sr=sample_rate2).T,axis=0)
mel2 = np.mean(lb.feature.melspectrogram(X2, sr=sample_rate2).T,axis=0)
contrast2 = np.mean(lb.feature.spectral_contrast(S=stft2, sr=sample_rate2).T,axis=0)
tonnetz2 = np.mean(lb.feature.tonnetz(y=librosa.effects.harmonic(X2), sr=sample_rate2).T,axis=0)

# %%
plt.plot(X2)
plt.show()
plt.plot(mfccs2)
plt.show()
plt.plot(chroma2)
plt.show()
plt.plot(mel2)
plt.show()
plt.plot(contrast2)
plt.show()
plt.plot(tonnetz2)
plt.show()

# %%
# plt.plot(X)
# plt.show()
plt.plot(mfccs)
plt.plot(mfccs1)
plt.plot(mfccs2)
plt.show()
plt.plot(chroma)
plt.plot(chroma1)
plt.plot(chroma2)
plt.show()
plt.plot(mel)
plt.plot(mel1)
plt.plot(mel2)
plt.show()
plt.plot(contrast)
plt.plot(contrast1)
plt.plot(contrast2)
plt.show()
plt.plot(tonnetz)
plt.plot(tonnetz1)
plt.plot(tonnetz2)
plt.show()
